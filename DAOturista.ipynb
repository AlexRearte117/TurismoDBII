# %%
from DAO import TuristaDAO
import importlib, sys
# Asegura que la raíz del proyecto está en el path
sys.path.append(r"C:\Users\reart\Documents\ESTUDIOS\DB-Turismo")

import turista
importlib.reload(turista)
from turista import turista_for_dao
print("todo joya")
# Out:
# todo joya

# %%
turista_for_dao.lugar_mas_visitado()
# Out:
# El lugar con ID 'None' es el más visitado, con 7 visitas.
# (None, 7)

# %%
turista_for_dao.log_visitas_por_lugar(1)
# Out:
# Log de visitas para el lugar con ID '1':

# %%
turista_for_dao.cantidad_comentarios()
# Out:
# Hay 3 comentarios registrados.
# 3

# %%
turista_for_dao.crear_turista(7, "Daniel", "Robins", "Cordoba", "me gusto el cristo")

# %%
turista_for_dao.obtener_todos_los_turistas()
# Out:
# {'_id': ObjectId('68a7283f3024b28e86064c6e'), 'ID': 1, 'Nombre': 'Nombre Anonimo', 'Apellido': 'Apellido Anonimo', 'Provincia': 'Provincia Desconocida', 'Comentario': 'Sin Comentario', 'fecha_hora': datetime.datetime(2025, 8, 21, 11, 7, 59, 213000)}
# {'_id': ObjectId('68a72870cdfc4a05706e5d47'), 'ID': 2, 'Nombre': 'Nombre Anonimo', 'Apellido': 'Apellido Anonimo', 'Provincia': 'Provincia Desconocida', 'Comentario': 'Sin Comentario', 'fecha_hora': datetime.datetime(2025, 8, 21, 11, 8, 48, 127000)}
# {'_id': ObjectId('68a72b332d1acdfc2ba607e6'), 'ID': 3, 'Nombre': 'Nombre Anonimo', 'Apellido': 'Apellido Anonimo', 'Provincia': 'Provincia Desconocida', 'Comentario': 'Sin Comentario', 'fecha_hora': datetime.datetime(2025, 8, 21, 11, 20, 35, 126000)}
# {'_id': 7, 'nombre': 'Daniel', 'apellido': 'Robins', 'provincia': 'Cordoba', 'comentario': 'me gusto el cristo'}
# {'_id': 4, 'nombre': 'Alex', 'apellido': 'Rearte', 'provincia': 'La Rioja', 'comentario': 'Es un lindo lugar'}
# ...

# %%
turista_for_dao.obtener_turista_por_apellido("Rearte")

# %%
turista_for_dao.obtener_turista_por_nombre("Alex")
# Out:
# {'_id': 4, 'nombre': 'Alex', 'apellido': 'Rearte', 'provincia': 'La Rioja', 'comentario': 'Es un lindo lugar'}

# %%
turista_for_dao.obtener_turistas_por_comentarios("me gusto el cristo")
# Out:
# {'_id': 7, 'nombre': 'Daniel', 'apellido': 'Robins', 'provincia': 'Cordoba', 'comentario': 'me gusto el cristo'}

# %%
turista_for_dao.obtener_turistas_por_provincia("La Rioja")

# %%
turista_for_dao.obtener_turista_por_id(7)

# %%
turista_for_dao.eliminar_turista_por_id(3)

# %%
turista_for_dao.crear_turista(7, "Daniel", "Robins", "Cordoba", "me gusto el cristo")

# %%
turista_for_dao.crear_turista(4, "Alex", "Rearte", "La Rioja", "Es un lindo lugar")

# %%
turista_for_dao.crear_turista(5, "Gabriel", "Rearte Fonzalida", "La Rioja", "Me gusto")

# %%
turista_for_dao.obtener_turistas_por_nombre_y_provincia("Alex", "La Rioja")

# %%
turista_for_dao.contar_turistas_por_provincia("La Rioja")

# %%
# Mostrar turistas anónimos
print("Turistas Anónimos:")
turista_for_dao.obtener_turistas_anonimos()
# Out:
# Turistas Anónimos:
# {'_id': ObjectId('68a7283f3024b28e86064c6e'), 'ID': 1, 'Nombre': 'Nombre Anonimo', 'Apellido': 'Apellido Anonimo', 'Provincia': 'Provincia Desconocida', 'Comentario': 'Sin Comentario', 'fecha_hora': datetime.datetime(2025, 8, 21, 11, 7, 59, 213000)}
# {'_id': ObjectId('68a72870cdfc4a05706e5d47'), 'ID': 2, 'Nombre': 'Nombre Anonimo', 'Apellido': 'Apellido Anonimo', 'Provincia': 'Provincia Desconocida', 'Comentario': 'Sin Comentario', 'fecha_hora': datetime.datetime(2025, 8, 21, 11, 8, 48, 127000)}
# {'_id': ObjectId('68a72b332d1acdfc2ba607e6'), 'ID': 3, 'Nombre': 'Nombre Anonimo', 'Apellido': 'Apellido Anonimo', 'Provincia': 'Provincia Desconocida', 'Comentario': 'Sin Comentario', 'fecha_hora': datetime.datetime(2025, 8, 21, 11, 20, 35, 126000)}
# ...

# %%
# Mostrar turistas registrados
print("Turistas Registrados:")
turista_for_dao.obtener_turistas_registrados()
# Out:
# Turistas Registrados:
# {'_id': 7, 'nombre': 'Daniel', 'apellido': 'Robins', 'provincia': 'Cordoba', 'comentario': 'me gusto el cristo'}
# {'_id': 4, 'nombre': 'Alex', 'apellido': 'Rearte', 'provincia': 'La Rioja', 'comentario': 'Es un lindo lugar'}
# {'_id': 5, 'nombre': 'Gabriel', 'apellido': 'Rearte', 'provincia': 'Buenos Aires', 'comentario': 'Me gusto'}
# Cantidad de turistas registrados: 3

# %%
turista_for_dao.actualizar_turista_por_id(5, nuevo_apellido="Rearte", nueva_provincia="Buenos Aires")
# Out:
# El turista con ID '5' fue actualizado exitosamente.

# %%
turista_for_dao.actualizar_turista_por_id(3, nuevo_nombre="Daniel", nuevo_apellido="Robins" ,nuevo_comentario="Muy buen lugar para visitar")
