# %%
import importlib
import lugaresTuristicos
importlib.reload(lugaresTuristicos)
from lugaresTuristicos import lugares_for_dao
from transformers import pipeline

# %%
#id, nombre, ubicacion, descripción, horario, comentarios[], visitas
lugares_for_dao.crear_lugar(3, "Estacion N2", "Chilecito", "Estacion N2", "Abierto a todo el publico", ["es un agradable lugar"], 23)

# %%
# Mostrar todas las visitas y comentarios
lugares_for_dao.mostrar_visitas_y_comentarios()

# Mostrar comentarios de un lugar específico
lugares_for_dao.mostrar_comentarios_por_lugar(1)  # Plaza Principal
lugares_for_dao.mostrar_comentarios_por_lugar(2)  # Cristo de Portezuelo
# Out:
# 🔍 REPORTE COMPLETO DE VISITAS Y COMENTARIOS
# ...
#
# 👤 TURISTA #1
#    📝 ID: 7
#    👨‍💼 Nombre: Daniel Robins
#    🏠 Provincia: Cordoba
#    🗓️ Fecha: Sin fecha
#    🏛️ Lugar visitado: N/A
#    💬 Comentario: 'me gusto el cristo'
# ------------------------------------------------------------
#
# 👤 TURISTA #2
#    📝 ID: 4
#    👨‍💼 Nombre: Alex Rearte
#    🏠 Provincia: La Rioja
#    🗓️ Fecha: Sin fecha
#    🏛️ Lugar visitado: N/A
#    💬 Comentario: 'Es un lindo lugar'
# ------------------------------------------------------------
#
# 👤 TURISTA #3
#    📝 ID: 5
#    👨‍💼 Nombre: Gabriel Rearte
#    🏠 Provincia: Buenos Aires
#    🗓️ Fecha: Sin fecha
#    🏛️ Lugar visitado: N/A
#    💬 Comentario: 'Me gusto'
# ------------------------------------------------------------
#
# 📊 RESUMEN:
#    Total de turistas con comentarios: 3
#    Visitas por lugar:
#      • Desconocido: 3 visitas
# 🏛️ COMENTARIOS DEL LUGAR: Plaza de Armas
# ...
# ❌ No hay comentarios para este lugar.
# ...

# %%
#id, nombre, ubicacion, descripción, horario, comentarios[], visitas
lugares_for_dao.crear_lugar(2, "Cristo de Portezuelo", "Chilecito", "Cristo de Portezuelo", "Abierto a todo el publico", [], 23)

# %%
lugares_for_dao.obtener_todos_los_lugares()
# Out:
# {'_id': 1, 'nombre': 'Plaza de Armas', 'ubicacion': 'Chilecito', 'descripción': 'Plaza principal de la ciudad', 'horario': 'Abierto a todo el publico', 'comentarios': [], 'visitas': 23}
# {'_id': 2, 'nombre': 'Cristo de Portezuelo', 'ubicacion': 'Chilecito', 'descripción': 'Cristo de Portezuelo', 'horario': 'Abierto a todo el publico', 'comentarios': [], 'visitas': 23}
# {'_id': 6, 'nombre': 'Plaza de Armas', 'ubicacion': 'Chilecito', 'descripción': 'Plaza principal de la ciudad', 'horario': 'Abierto a todo el publico', 'comentarios': [], 'visitas': 23}
# {'_id': 3, 'nombre': 'Estacion N2', 'ubicacion': 'Chilecito', 'descripción': 'Estacion N2', 'horario': 'Abierto a todo el publico', 'comentarios': ['es un agradable lugar', {'turista_id': 1, 'texto': 'es un agradable luaasasasasgar', 'comentario': 'HIJOS DE PUTA'}, {'turista_id': 1, 'texto': 'es un agradable luaasasasasgar'}], 'visitas': 23}

# %%
lugares_for_dao.obtener_Estrellas_Comentarios(6)

# %%
lugares_for_dao.Eliminar_Lugar_por_id(2)

# %%
lugares_for_dao.Obtener_lugar_por_visitas_mayor(21)

# %%
#id, turista_id, texto
lugares_for_dao.agregar_comentario_a_lugar(3, 1, "es un agradable luaasasasasgar")

# %%
lugares_for_dao.editar_comentario_a_lugar(3, 1, "HIJOS DE PUTA")
# Out:
# Comentario 1 editado en el lugar con ID 3.

# %%
lugares_for_dao.Obtener_lugar_por_visitas_menor(21)

# %%
lugares_for_dao.obtener_lugar_por_nombre("Cristo de Portezuelo")
# Out:
# {'_id': 2, 'nombre': 'Cristo de Portezuelo', 'ubicacion': 'Chilecito', 'descripción': 'Cristo de Portezuelo', 'horario': 'Abierto a todo el publico', 'comentarios': [], 'visitas': 23}

# %%
lugares_for_dao.obtener_lugar_por_ubicacion("Chilecito")
