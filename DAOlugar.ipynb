# %%
import importlib
import lugaresTuristicos
importlib.reload(lugaresTuristicos)
from lugaresTuristicos import lugares_for_dao

# %%
#id, nombre, ubicacion, descripción, horario, comentarios[], visitas
lugares_for_dao.crear_lugar(1, "Plaza de Armas", "Chilecito", "Plaza principal de la ciudad", "Abierto a todo el publico", [], 23)
# Out:
# ---------------------------------------------------------------------------
# DuplicateKeyError                         Traceback (most recent call last)
# Cell In[34], line 2
#       1 #id, nombre, ubicacion, descripción, horario, comentarios[], visitas
# ----> 2 lugares_for_dao.crear_lugar(1, "Plaza de Armas", "Chilecito", "Plaza principal de la ciudad", "Abierto a todo el publico", [], 23)
#
# File c:\Users\reart\Documents\ESTUDIOS\DB-Turismo\lugaresTuristicos.py:20, in lugares_for_dao.crear_lugar(id, nombre, ubicacion, descripción, horario, comentarios, visitas)
#       9 @staticmethod
#      10 def crear_lugar(id, nombre, ubicacion, descripción, horario, comentarios, visitas):
#      11     lugar = {
#      12         "_id" : id,
#      13         "nombre": nombre,
#    (...)     18         "visitas": visitas
#      19     }
# ---> 20     collection_lugares.insert_one(lugar)
#      21     print("Lugar creado")
#
# File c:\Users\reart\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\collection.py:891, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     887     document["_id"] = ObjectId()  # type: ignore[index]
#     889 write_concern = self._write_concern_for(session)
#     890 return InsertOneResult(
# --> 891     self._insert_one(
#     892         document,
#     893         ordered=True,
#     894         write_concern=write_concern,
#     895         op_id=None,
#     896         bypass_doc_val=bypass_document_validation,
#     897         session=session,
#     898         comment=comment,
#     899     ),
#     900     write_concern.acknowledged,
#     901 )
#
# File c:\Users\reart\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\collection.py:831, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     819     result = conn.command(
#     820         self._database.name,
#     821         command,
#    (...)    826         retryable_write=retryable_write,
#     827     )
#     829     _check_write_command_response(result)
# --> 831 self._database.client._retryable_write(
#     832     acknowledged, _insert_command, session, operation=_Op.INSERT
#     833 )
#     835 if not isinstance(doc, RawBSONDocument):
#     836     return doc.get("_id")
#
# File c:\Users\reart\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\mongo_client.py:2076, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2062 """Execute an operation with consecutive retries if possible
#    2063
#    2064 Returns func()'s return value on success. On error retries the same
#    (...)   2073 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    2074 """
#    2075 with self._tmp_session(session) as s:
# -> 2076     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File c:\Users\reart\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\mongo_client.py:1962, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1957 # Ensure that the options supports retry_writes and there is a valid session not in
#    1958 # transaction, otherwise, we will not support retry behavior for this txn.
#    1959 retryable = bool(
#    1960     retryable and self.options.retry_writes and session and not session.in_transaction
#    1961 )
# -> 1962 return self._retry_internal(
#    1963     func=func,
#    1964     session=session,
#    1965     bulk=bulk,
#    1966     operation=operation,
#    1967     retryable=retryable,
#    1968     operation_id=operation_id,
#    1969 )
#
# File c:\Users\reart\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\reart\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\mongo_client.py:2008, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1971 @_csot.apply
#    1972 def _retry_internal(
#    1973     self,
#    (...)   1982     operation_id: Optional[int] = None,
#    1983 ) -> T:
#    1984     """Internal retryable helper for all client transactions.
#    1985
#    1986     :param func: Callback function we want to retry
#    (...)   1995     :return: Output of the calling func()
#    1996     """
#    1997     return _ClientConnectionRetryable(
#    1998         mongo_client=self,
#    1999         func=func,
#    2000         bulk=bulk,
#    2001         operation=operation,
#    2002         is_read=is_read,
#    2003         session=session,
#    2004         read_pref=read_pref,
#    2005         address=address,
#    2006         retryable=retryable,
#    2007         operation_id=operation_id,
# -> 2008     ).run()
#
# File c:\Users\reart\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\mongo_client.py:2745, in _ClientConnectionRetryable.run(self)
#    2743 self._check_last_error(check_csot=True)
#    2744 try:
# -> 2745     return self._read() if self._is_read else self._write()
#    2746 except ServerSelectionTimeoutError:
#    2747     # The application may think the write was never attempted
#    2748     # if we raise ServerSelectionTimeoutError on the retry
#    2749     # attempt. Raise the original exception instead.
#    2750     self._check_last_error()
#
# File c:\Users\reart\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\mongo_client.py:2877, in _ClientConnectionRetryable._write(self)
#    2869         if self._retrying:
#    2870             _debug_log(
#    2871                 _COMMAND_LOGGER,
#    2872                 message=f"Retrying write attempt number {self._attempt_number}",
#    (...)   2875                 operationId=self._operation_id,
#    2876             )
# -> 2877         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2878 except PyMongoError as exc:
#    2879     if not self._retryable:
#
# File c:\Users\reart\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\collection.py:829, in Collection._insert_one.<locals>._insert_command(session, conn, retryable_write)
#     817     command["bypassDocumentValidation"] = bypass_doc_val
#     819 result = conn.command(
#     820     self._database.name,
#     821     command,
#    (...)    826     retryable_write=retryable_write,
#     827 )
# --> 829 _check_write_command_response(result)
#
# File c:\Users\reart\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\helpers_shared.py:322, in _check_write_command_response(result)
#     320 write_errors = result.get("writeErrors")
#     321 if write_errors:
# --> 322     _raise_last_write_error(write_errors)
#     324 wce = _get_wce_doc(result)
#     325 if wce:
#
# File c:\Users\reart\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\helpers_shared.py:292, in _raise_last_write_error(write_errors)
#     290 error = write_errors[-1]
#     291 if error.get("code") == 11000:
# --> 292     raise DuplicateKeyError(error.get("errmsg"), 11000, error)
#     293 raise WriteError(error.get("errmsg"), error.get("code"), error)
#
# DuplicateKeyError: E11000 duplicate key error collection: Turismo.lugar index: _id_ dup key: { _id: 1 }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Turismo.lugar index: _id_ dup key: { _id: 1 }', 'keyPattern': {'_id': 1}, 'keyValue': {'_id': 1}}

# %%
#id, nombre, ubicacion, descripción, horario, comentarios[], visitas
lugares_for_dao.crear_lugar(2, "Cristo de Portezuelo", "Chilecito", "Cristo de Portezuelo", "Abierto a todo el publico", [], 23)
# Out:
# Lugar creado

# %%
lugares_for_dao.obtener_todos_los_lugares()
# Out:
# {'_id': 1, 'nombre': 'Plaza de Armas', 'ubicacion': 'Chilecito', 'descripción': 'Plaza principal de la ciudad', 'horario': 'Abierto a todo el publico', 'comentarios': [], 'visitas': 23}
# {'_id': 2, 'nombre': 'Cristo de Portezuelo', 'ubicacion': 'Chilecito', 'descripción': 'Cristo de Portezuelo', 'horario': 'Abierto a todo el publico', 'comentarios': [], 'visitas': 23}

# %%
turista_for_dao.crear_turista(7, "Daniel", "Robins", "Cordoba", "me gusto el cristo")

# %%
turista_for_dao.crear_turista(7, "Daniel", "Robins", "Cordoba", "me gusto el cristo")

# %%
lugares_for_dao.obtener_Estrellas_Comentarios(1)
# Out:
# No se encontró el lugar con ID 1 o no tiene comentarios.

# %%
lugares_for_dao.Eliminar_Lugar_por_id(2)
# Out:
# Lugar con ID 2 eliminado.

# %%
lugares_for_dao.Obtener_lugar_por_visitas_mayor(21)
# Out:
# {'_id': 1, 'nombre': 'Plaza de Armas', 'ubicacion': 'Chilecito', 'descripción': 'Plaza principal de la ciudad', 'horario': 'Abierto a todo el publico', 'comentarios': [], 'visitas': 23}
# {'_id': 2, 'nombre': 'Cristo de Portezuelo', 'ubicacion': 'Chilecito', 'descripción': 'Cristo de Portezuelo', 'horario': 'Abierto a todo el publico', 'comentarios': [], 'visitas': 23}

# %%
lugares_for_dao.Obtener_lugar_por_visitas_menor(21)

# %%
lugares_for_dao.obtener_lugar_por_nombre("Cristo de Portezuelo")
# Out:
# {'_id': 2, 'nombre': 'Cristo de Portezuelo', 'ubicacion': 'Chilecito', 'descripción': 'Cristo de Portezuelo', 'horario': 'Abierto a todo el publico', 'comentarios': [], 'visitas': 23}

# %%
lugares_for_dao.obtener_lugar_por_ubicacion("Chilecito")
# Out:
# {'_id': 1, 'nombre': 'Plaza de Armas', 'ubicacion': 'Chilecito', 'descripción': 'Plaza principal de la ciudad', 'horario': 'Abierto a todo el publico', 'comentarios': [], 'visitas': 23}
# {'_id': 2, 'nombre': 'Cristo de Portezuelo', 'ubicacion': 'Chilecito', 'descripción': 'Cristo de Portezuelo', 'horario': 'Abierto a todo el publico', 'comentarios': [], 'visitas': 23}

# %%
turista_for_dao.crear_turista(7, "Daniel", "Robins", "Cordoba", "me gusto el cristo")

# %%
turista_for_dao.crear_turista(7, "Daniel", "Robins", "Cordoba", "me gusto el cristo")

# %%
turista_for_dao.crear_turista(7, "Daniel", "Robins", "Cordoba", "me gusto el cristo")
